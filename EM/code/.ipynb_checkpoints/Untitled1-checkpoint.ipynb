# %%
from EMUtils.config import *
from EMUtils.EM import EM
from matplotlib import pyplot as plt

# %%
em = EM()

# %%
plt.imshow(visible_image, cmap='gray')

# %%
plt.imshow(disparity_image, cmap='gray')

# %%
em.estimation()
# Out:
# 124

# %%
plt.imshow(visible_image, cmap='gray')

# %%
plt.imshow(disparity_image, cmap='gray')

# %%
em.maxmization()
# Out:
# 10

# %%
em.estimation()
# Out:
# 124

# %%
plt.imshow(disparity_image, cmap='gray')

# %%
plt.imshow(visible_image, cmap='gray')

# %%
em.maxmization()
# Out:
# 4.903708275960306

# %%
disparity_image
# Out:
# array([[12.50000079, 12.50000161, 12.50000249, ..., 12.49999959,
#         12.49999893, 12.49999975],
#        [12.50000079, 12.50000162, 12.50000249, ..., 12.499999  ,
#         12.49999915, 12.50000013],
#        [12.50000079, 12.50000161, 12.50000249, ..., 12.49999819,
#         12.49999971, 12.49999957],
#        ...,
#        [12.50000079, 12.50000162, 12.50000249, ..., 12.50000104,
#         12.50000086, 12.50000048],
#        [12.50000079, 12.50000142, 12.50000209, ..., 12.50000089,
#         12.50000097, 12.5       ],
#        [12.5000004 , 12.50000062, 12.50000085, ..., 12.50000048,
#         12.5       , 12.5       ]])

# %%
true_disparity_image[HEIGHT - 1 - 10, WIDTH - 1 - 10]
# Out:
# 20

# %%
print(image1[HEIGHT - 1 - 10, WIDTH - 1 - 10])
print(image2[HEIGHT - 1 - 10, WIDTH - 1 -  10 - 20])
# Out:
# 48
# 52

# %%
visible_image
# Out:
# array([[0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#         3.35036843e-01, 5.20234929e-01, 3.45967322e-01],
#        [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#         2.49024786e-01, 3.25283362e-01, 5.71852536e-01],
#        [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#         3.60589573e-01, 2.49053192e-01, 5.16199539e-01],
#        ...,
#        [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#         1.57086792e-09, 1.01671293e-01, 2.50582985e-01],
#        [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#         2.86436164e-01, 3.39349715e-01, 3.27718548e-01],
#        [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#         2.44059378e-01, 1.60589237e-01, 2.88844953e-01]])

# %%
from EMUtils import utils

# %%
utils.map_m_to_r_s(47)
# Out:
# (23, 1)

# %%
visible_state
# Out:
# array([[25., 25., 25., ..., 23., 22., 23.],
#        [25., 25., 25., ..., 23., 23., 24.],
#        [25., 25., 25., ..., 23., 23., 22.],
#        ...,
#        [25., 25., 25., ..., 25., 25., 25.],
#        [25., 25., 25., ..., 25., 25., 25.],
#        [25., 25., 25., ..., 25., 25., 25.]])

# %%
hist_mat[1]
# Out:
# array([0.        , 0.00024332, 0.00018249, 0.00060831, 0.00152077,
#        0.00194659, 0.00340653, 0.00462315, 0.00802969, 0.02007421,
#        0.0579719 , 0.04896892, 0.03893181, 0.06922562, 0.06946895,
#        0.06740069, 0.0748829 , 0.10085772, 0.11904617, 0.10979987,
#        0.07579536, 0.07865442, 0.02512318, 0.00839467, 0.00693473,
#        0.0051098 , 0.00206825, 0.00054748, 0.00018249, 0.        ,
#        0.        , 0.        ])

# %%
utils.norm_pdf(4.8, 5.2, 1)
# Out:
# 0.3682701403033233

# %%
utils.hist_prob(0, 149)
# Out:
# 0.03125

# %%
image1
# Out:
# array([[ 95,  78,  98, ..., 161, 164, 170],
#        [142,  75, 120, ..., 164, 163, 173],
#        [ 97,  94, 107, ..., 167, 163, 164],
#        ...,
#        [155, 153, 150, ...,  62, 106, 125],
#        [145, 143, 142, ...,  92, 109, 111],
#        [144, 146, 144, ..., 152, 148, 149]])

# %%
ideal_image
# Out:
# array([[ 95,  78,  98, ..., 161, 170, 170],
#        [142,  75, 120, ..., 164, 163, 174],
#        [ 97,  94, 107, ..., 167, 163, 171],
#        ...,
#        [155, 153, 150, ...,  62, 106, 125],
#        [145, 143, 142, ...,  92, 109, 111],
#        [144, 146, 144, ..., 152, 148, 149]])

# %%
image1
# Out:
# array([[ 95,  78,  98, ..., 161, 164, 170],
#        [142,  75, 120, ..., 164, 163, 173],
#        [ 97,  94, 107, ..., 167, 163, 164],
#        ...,
#        [155, 153, 150, ...,  62, 106, 125],
#        [145, 143, 142, ...,  92, 109, 111],
#        [144, 146, 144, ..., 152, 148, 149]])

# %%
image2
# Out:
# array([[119, 136, 168, ..., 161, 129, 110],
#        [121, 163, 163, ..., 164, 156, 119],
#        [114, 167, 107, ..., 169, 161, 155],
#        ...,
#        [161, 159, 163, ..., 167, 169, 175],
#        [162, 161, 163, ..., 174, 174, 171],
#        [166, 163, 161, ..., 195, 197, 195]])

# %%
plt.imshow(ideal_image, cmap = 'gray')
