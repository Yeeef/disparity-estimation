# %% [markdown]
# 再次惩罚 hist_mat, 是原来的十分之一

# %%
from EMUtils.config import *
from EMUtils.EM import EM
from matplotlib import pyplot as plt

# %%
em = EM()

# %%
disparity_image
# Out:
# array([[ 1,  2,  3, ..., 21, 18, 10],
#        [ 1,  2,  3, ..., 19,  1, 10],
#        [ 1,  2,  3, ...,  5, 14, 15],
#        ...,
#        [ 1,  2,  3, ..., 15,  1, 14],
#        [ 1,  2,  3, ..., 15, 15, 16],
#        [ 1,  2,  3, ..., 15, 16, 17]])

# %%
plt.imshow(visible_image, cmap='gray')

# %%
plt.imshow(disparity_image, cmap="gray")

# %%
em.maxmization()

# %% [markdown]
# 非常奇特，不做em的时候，反而不会使 covariance 飞出去
# 这次试试不再先做 maxmization

# %%
plt.imshow(ideal_image, cmap="gray")

# %%
em.estimation()
# Out:
# 124

# %%
plt.imshow(visible_image, cmap='gray')

# %%
plt.imshow(disparity_image, cmap="gray")

# %%
disparity_image[:, 20:]

# %%
em.maxmization()
# Out:
# covariance: 1.3968932716641942

# %%
disparity_image

# %%
true_disparity_image - disparity_image
# Out:
# array([[ -6,  -6,  -6, ..., -12, -10,  -2],
#        [ -6,  -6,  -7, ..., -10, -11,  -2],
#        [ -6,  -6,  -6, ...,   4,  -5,  -6],
#        ...,
#        [ 11,  11,  10, ...,   3,  -8,  -8],
#        [ 11,  11,  10, ...,   4,   5,   5],
#        [ 11,  11,  10, ...,   6,   5,   4]])

# %%
plt.imshow(ideal_image, cmap="gray")

# %%
em.estimation()
# Out:
# 124

# %%
plt.imshow(visible_image, cmap='gray')

# %%
plt.imshow(disparity_image, cmap="gray")

# %%
em.maxmization()
# Out:
# covariance: 1.131942412360274

# %%
plt.imshow(ideal_image, cmap="gray")

# %%
em.estimation()
# Out:
# 124

# %%
plt.imshow(visible_image, cmap='gray')

# %%
plt.imshow(disparity_image, cmap="gray")

# %%
em.maxmization()
# Out:
# covariance: 0.9344330018590103

# %%
plt.imshow(ideal_image, cmap="gray")

# %%
from PIL import Image
test = Image.fromarray(ideal_image.astype("uint8"), "L")

# %%
test = Image.fromarray(disparity_image.astype("uint8"), "L")

# %%
disparity_image
# Out:
# array([[13, 13, 13, ..., 21, 18, 10],
#        [13, 13, 14, ..., 19, 20, 11],
#        [13, 13, 13, ..., 19, 14, 15],
#        ...,
#        [13, 13, 14, ...,  5,  6, 14],
#        [13, 13, 14, ..., 15, 15, 16],
#        [13, 13, 14, ..., 15,  6,  7]])

# %%
test = Image.fromarray(9 * true_disparity_image.astype("uint8"), "L")

# %%
plt.imshow(true_disparity_image, cmap="gray")

# %%
test
# Out:
# <PIL.Image.Image image mode=L size=150x125 at 0x7FA552CA1898>
