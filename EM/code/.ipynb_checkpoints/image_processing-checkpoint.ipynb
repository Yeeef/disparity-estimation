# %%
from PIL import Image
from matplotlib import pyplot as plt

# %%
disp = Image.open("/home/vradmin/Desktop/paper_work/EM/data/cones/disp2.png")

# %%
import numpy as np

# %%
disp_small_mat = np.array(disp) / 9

# %%
disp_small = Image.fromarray(disp_small_mat.astype('uint8'))

# %%
np.array(disp_small.resize([150, 125], I))
# Out:
# array([[ 7,  7,  7, ...,  9,  9,  9],
#        [ 7,  7,  7, ...,  9,  9,  9],
#        [ 7,  7,  7, ...,  9,  9,  9],
#        ...,
#        [24, 24, 24, ..., 19,  0,  0],
#        [24, 24, 24, ..., 19, 19, 20],
#        [24, 24, 24, ..., 21, 21, 21]], dtype=uint8)

# %%
disp_before = Image.open("/home/vradmin/Desktop/paper_work/EM/data/cones/disp2_small.png")

# %%
(np.array(disp_before) / 9).astype('uint8')
# Out:
# array([[ 7,  7,  7, ...,  9,  8,  8],
#        [ 7,  7,  7, ...,  9,  9,  9],
#        [ 7,  7,  7, ...,  9,  9,  9],
#        ...,
#        [24, 24, 24, ..., 18,  7,  7],
#        [24, 24, 24, ..., 19, 20, 21],
#        [24, 24, 24, ..., 21, 21, 21]], dtype=uint8)

# %%
view1 = Image.open("/home/vradmin/Desktop/paper_work/EM/data/Aloe/view1.png")
view5 = Image.open("/home/vradmin/Desktop/paper_work/EM/data/Aloe/view5.png")
disp1 = Image.open("/home/vradmin/Desktop/paper_work/EM/data/Aloe/disp1.png")

# %%
view1_small = view1.resize([142, 123]).convert("L")

# %%
plt.savefig(view1_small)

# %%
view1_small.save("/home/vradmin/Desktop/paper_work/EM/data/Aloe/disp1.png", quality=100)

# %%
view5_small = view5.resize([142, 123]).convert("L")

# %%
plt.imshow(view5_small)

# %%
view5_small.save("/home/vradmin/Desktop/paper_work/EM/data/Aloe/disp1.png", quality=100)

# %%
disp1_small = disp1.resize([142, 123])

# %%
disp1_small
# Out:
# <PIL.Image.Image image mode=L size=142x123 at 0x7F29835904E0>

# %%
disp1_mat = np.array(disp1)

# %%
disp1_mat / 9
# Out:
# array([[ 4.88888889,  4.88888889,  4.88888889, ...,  5.22222222,
#          5.22222222,  5.22222222],
#        [ 4.88888889,  4.88888889,  4.88888889, ...,  5.22222222,
#          5.22222222,  5.22222222],
#        [ 4.88888889,  4.88888889,  4.88888889, ...,  5.11111111,
#          5.11111111,  5.11111111],
#        ...,
#        [16.88888889, 16.88888889, 16.88888889, ..., 13.88888889,
#         14.        , 14.        ],
#        [16.88888889, 16.88888889, 16.88888889, ..., 14.11111111,
#         14.11111111, 14.11111111],
#        [17.        , 17.        , 17.        , ..., 14.11111111,
#         14.22222222, 14.22222222]])

# %%
view1.crop
# Out:
# <bound method Image.crop of <PIL.Image.Image image mode=L size=427x370 at 0x7F298B5C5AC8>>

# %%
view1_mat = np.array(view1)

# %%
view1_mat.shape
# Out:
# (370, 427)

# %%
np.array(view5)
# Out:
# array([[170, 145, 141, ..., 186, 171, 184],
#        [173, 183, 185, ..., 202, 193, 194],
#        [182, 192, 189, ..., 183, 200, 197],
#        ...,
#        [200, 217, 236, ..., 180, 180, 182],
#        [208, 194, 221, ..., 159, 167, 179],
#        [216, 206, 193, ..., 183, 183, 180]], dtype=uint8)

# %%
np.array(disp1)
# Out:
# array([[ 44,  44,  44, ...,  47,  47,  47],
#        [ 44,  44,  44, ...,  47,  47,  47],
#        [ 44,  44,  44, ...,  46,  46,  46],
#        ...,
#        [152, 152, 152, ..., 125, 126, 126],
#        [152, 152, 152, ..., 127, 127, 127],
#        [153, 153, 153, ..., 127, 128, 128]], dtype=uint8)

# %%
plt.imshow(view1)

# %%
plt.imshow(view5)
