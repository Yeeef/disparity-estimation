# %%
"""
without occlusion
sigma_d = 10
sigma_v = 1
expectation method
print free_energy
"""

from EMUtils.EM import EM
from EMUtils.config import *
from PIL import Image
from matplotlib import pyplot as plt

# %%
em = EM("/home/vradmin/Desktop/paper_work/EM/result/without_occlusion_2/")

# %%
plt.imshow(visible_image, cmap="gray")

# %%
plt.imshow(disparity_image, cmap="gray")

# %%
em.e_and_m()
# Out:
# 124
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-5-ba0c00b8a19b> in <module>()
# ----> 1 em.e_and_m()
#
# ~/Desktop/paper_work/EM/code/EMUtils/EM.py in e_and_m(self)
#      19
#      20     def e_and_m(self):
# ---> 21         self.estimation()
#      22         print(f"\n {self.iter} E step finished")
#      23         self.maxmization()
#
# ~/Desktop/paper_work/EM/code/EMUtils/EM.py in estimation(self)
#      13
#      14     def estimation(self):
# ---> 15         Estep.E_step()
#      16
#      17     def maxmization(self):
#
# ~/Desktop/paper_work/EM/code/EMUtils/Estep.py in E_step()
#     140 def E_step():
#     141     update_b()
# --> 142     update_visible_expectation()
#     143     # update_visible()
#     144
#
# ~/Desktop/paper_work/EM/code/EMUtils/Estep.py in update_visible_expectation(b)
#     130             nearest_visibility = utils.nearest_int(visibility)
#     131             visible_image[i, j] = nearest_visibility
# --> 132             new_r = depth_vec.index(nearest_disparity)
#     133             if nearest_visibility == 1:
#     134                 new_s = 0
#
# ValueError: 0 is not in list
