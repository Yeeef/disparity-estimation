# %% [markdown]
# 再次惩罚 hist_mat, 是原来的十分之一

# %%
from EMUtils.config import *
from EMUtils.EM import EM
from matplotlib import pyplot as plt

# %%
em = EM()

# %%
disparity_image
# Out:
# array([[ 1.,  2.,  3., ..., 21., 18., 10.],
#        [ 1.,  2.,  3., ..., 19.,  1., 10.],
#        [ 1.,  2.,  3., ...,  5., 14., 15.],
#        ...,
#        [ 1.,  2.,  3., ..., 15.,  1., 14.],
#        [ 1.,  2.,  3., ..., 15., 15., 16.],
#        [ 1.,  2.,  3., ..., 15., 16., 17.]])

# %%
plt.imshow(visible_image, cmap='gray')

# %%
plt.imshow(disparity_image, cmap="gray")

# %%
em.maxmization()
# Out:
# 1.3968932716641942

# %% [markdown]
# 非常奇特，不做em的时候，反而不会使 covariance 飞出去

# %%
plt.imshow(ideal_image, cmap="gray")

# %%
em.estimation()
# Out:
# 124

# %%
plt.imshow(visible_image, cmap='gray')

# %%
plt.imshow(disparity_image, cmap="gray")

# %%
em.maxmization()
# Out:
# 238.52973414179104

# %%
plt.imshow(ideal_image)

# %%
disparity_image
# Out:
# array([[12.50028918, 12.50088776, 12.50152544, ..., 12.50200938,
#         12.49968574, 12.49864285],
#        [12.50029006, 12.50089021, 12.50153028, ..., 12.49935766,
#         12.49889954, 12.49922442],
#        [12.50029006, 12.50089031, 12.50153001, ..., 12.49862713,
#         12.49823548, 12.50037552],
#        ...,
#        [12.50028999, 12.50089038, 12.50153035, ..., 12.50073783,
#         12.50202633, 12.5014939 ],
#        [12.50029006, 12.50089045, 12.50153039, ..., 12.50265263,
#         12.50322584, 12.50239993],
#        [12.50029012, 12.50060228, 12.50093249, ..., 12.50173393,
#         12.50239914, 12.50000246]])
