# %%
from EMUtils.EM import EM
from EMUtils.config import *
from PIL import Image
from matplotlib import pyplot as plt

# %%
em = EM("/home/vradmin/Desktop/paper_work/EM/code/aloe_output")

# %%
plt.imshow(visible_image, cmap="gray")

# %%
plt.imshow(disparity_image, cmap="gray")

# %%
em.maxmization()
# Out:
# covariance: 4.0370860927152314

# %%
em.e_and_m()
# Out:
# 369
#  0 E step finished
# covariance: 89.34275159339099
#
#  0 M step finished
#
#  0 save fig successfully in /home/vradmin/Desktop/paper_work/EM/code/aloe_output
