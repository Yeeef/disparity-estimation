# %%
"""
sigma_d = 30000
sigma_v = 300
expectation method
"""

from EMUtils.EM import EM
from EMUtils.config import *
from PIL import Image
from matplotlib import pyplot as plt

# %%
em = EM("/home/vradmin/Desktop/paper_work/EM/result/without_occlusion/")

# %%
plt.imshow(visible_image, cmap="gray")

# %%
plt.imshow(disparity_image, cmap="gray")

# %%
em.e_and_m()
# Out:
# 124
#  0 E step finished
# covariance: 121.4095910317625
#
#  0 M step finished
#
#  0 save fig successfully in /home/vradmin/Desktop/paper_work/EM/result/without_occlusion/

# %%
em.e_and_m()
# Out:
# 124
#  1 E step finished
# covariance: 6.330043406366267
#
#  1 M step finished
#
#  1 save fig successfully in /home/vradmin/Desktop/paper_work/EM/result/without_occlusion/
